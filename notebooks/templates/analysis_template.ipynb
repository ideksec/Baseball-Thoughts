# %% [markdown]
# # [Question title]
#
# | Field | Value |
# |-------|-------|
# | **Question** | What are we trying to answer? |
# | **Datasets** | List sources and tables used |
# | **Time window** | e.g., 2020–2024 regular season |
# | **Assumptions** | Key assumptions or scope limits |

# %%
# --- Setup ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
# from baseball_lab.metrics.batting import batting_avg, ops

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## Method
#
# Describe what was done — the approach, not every attempt.

# %%
# Analysis code here

# %% [markdown]
# ## Results
#
# Minimal charts or tables that answer the question.

# %%
# Results / visualization code here

# %% [markdown]
# ## Conclusion
#
# 5–10 sentences summarizing findings, limitations, and the suggested next step.
#
# - **Finding:**
# - **Limitations:**
# - **Next step:**
